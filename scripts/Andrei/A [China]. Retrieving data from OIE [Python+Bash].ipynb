# %% [markdown]
# # Preamble

# %%
import urllib.request
from bs4 import BeautifulSoup
import re
import os

import pandas as pd
import numpy as np
from itertools import cycle

def shift(l, n):
    return l[n:] + l[:n]

# %% [markdown]
# # List of html files downloaded manually from [OIE web-site](https://www.oie.int/wahis_2/public/wahid.php/Diseaseinformation/reportarchive)

# %%
htmlFiles = !ls ../../data/htmls/
print(htmlFiles)
# Out:
# ['200502.html', '200503.html', '200504.html', '200505.html', '200506.html', '200507.html', '200508.html', '200509.html', '200510.html', '200511.html', '200512.html', '200601.html', '200602.html', '200603.html', '200604.html', '200605.html', '200606.html', '200607.html', '200608.html', '200609.html', '200610.html', '200611.html', '200612.html', '200701.html', '200702.html', '200703.html', '200704.html', '200705.html', '200706.html', '200707.html', '200708.html', '200709.html', '200710.html', '200711.html', '200712.html', '200801.html', '200802.html', '200803.html', '200804.html', '200805.html', '200806.html', '200807.html', '200808.html', '200809.html', '200810.html', '200811.html', '200812.html', '200901.html', '200902.html', '200903.html', '200904.html', '200905.html', '200906.html', '200907.html', '200908.html', '200909.html', '200910.html', '200911.html', '200912.html', '201001.html', '201002.html', '201003.html', '201004.html', '201005.html', '201006.html', '201007.html', '201008.html', '201009.html', '201010.html', '201011.html', '201012.html', '201101.html', '201102.html', '201103.html', '201104.html', '201105.html', '201106.html', '201107.html', '201108.html', '201109.html', '201110.html', '201111.html', '201112.html', '201201.html', '201202.html', '201203.html', '201204.html', '201205.html', '201206.html', '201207.html', '201208.html', '201209.html', '201210.html', '201211.html', '201212.html', '201301.html', '201302.html', '201303.html', '201304.html', '201305.html', '201306.html', '201307.html', '201308.html', '201309.html', '201310.html', '201311.html', '201312.html', '201401.html', '201402.html', '201403.html', '201404.html', '201405.html', '201406.html', '201407.html', '201408.html', '201409.html', '201410.html', '201411.html', '201412.html', '201501.html', '201502.html', '201503.html', '201504.html', '201505.html', '201506.html', '201507.html', '201508.html', '201509.html', '201510.html', '201511.html', '201512.html', '201601.html', '201602.html', '201603.html', '201604.html', '201605.html', '201606.html', '201607.html', '201608.html', '201609.html', '201610.html', '201611.html', '201612.html', '201701.html', '201702.html', '201703.html', '201704.html', '201705.html', '201706.html', '201707.html', '201708.html', '201709.html', '201710.html', '201711.html', '201712.html', '201801.html', '201802.html', '201803.html', '201804.html', '201805.html', '201806.html', '201807.html', '201808.html', '201809.html', '201810.html', '201811.html', '201812.html', '201901.html', '201902.html', '201903.html', '201904.html', '201905.html', '201906.html', '201907.html', '201908.html', '201909.html', '201910.html', '201911.html']

# %% [markdown]
# # Retrieving the list of links for pdf-files stored on OIE website

# %%
links = []
for htmlFile in htmlFiles:
    if(int(htmlFile[:4])>2018 or (int(htmlFile[:4])==2018 and int(htmlFile[4:6])>=8)):
        infile = open("../../data/htmls/"+htmlFile,"r", encoding = "ISO-8859-1")
        contents = infile.read()
        soup = BeautifulSoup(contents,'html.parser')
        cells = soup.find_all("a",href=re.compile("pdf"))
        links = links + [a['href'] for a in cells if ("African swine fever" in a.get_text()) and (("China" in a.get_text()))] #or ("Hong Kong" in a.get_text())
links[1:5]
# Out:
# ['https://www.oie.int/wahis_2/temp/reports/en_imm_0000027636_20180823_183422.pdf',
#  'https://www.oie.int/wahis_2/temp/reports/en_imm_0000027598_20180820_154827.pdf',
#  'https://www.oie.int/wahis_2/temp/reports/en_fup_0000027570_20180816_175933.pdf',
#  'https://www.oie.int/wahis_2/temp/reports/en_imm_0000027568_20180816_165812.pdf']

# %% [markdown]
# # Downloading pdf-files

# %%
pdfsDir = "../../data/ASF_pdfs"
# !rm -rf {pdfsDir}
# !mkdir -p {pdfsDir}

# %%
up_to_date = True
for link in links:
    if not os.path.exists(pdfsDir+"/"+link.split("/")[-1]):
        # !wget --random-wait -r -p -nd -e robots=off --directory-prefix={pdfsDir} {link}
        up_to_date = False
if (up_to_date):
    print("The dataset is up to date")
# Out:
# --2019-11-23 21:10:49--  https://www.oie.int/wahis_2/temp/reports/en_fup_0000031892_20190924_175316.pdf
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving www.oie.int (www.oie.int)... 51.254.148.117
# Connecting to www.oie.int (www.oie.int)|51.254.148.117|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58667 (57K) [application/pdf]
# Saving to: ‘../../data/ASF_pdfs/en_fup_0000031892_20190924_175316.pdf’
#
# en_fup_0000031892_2 100%[===================>]  57.29K   210KB/s    in 0.3s
#
# 2019-11-23 21:10:51 (210 KB/s) - ‘../../data/ASF_pdfs/en_fup_0000031892_20190924_175316.pdf’ saved [58667/58667]
#
# FINISHED --2019-11-23 21:10:51--
# Total wall clock time: 2.2s
# Downloaded: 1 files, 57K in 0.3s (210 KB/s)
# --2019-11-23 21:10:51--  https://www.oie.int/wahis_2/temp/reports/en_fup_0000031697_20190912_111711.pdf
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving www.oie.int (www.oie.int)... 51.254.148.117
# Connecting to www.oie.int (www.oie.int)|51.254.148.117|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 56587 (55K) [application/pdf]
# Saving to: ‘../../data/ASF_pdfs/en_fup_0000031697_20190912_111711.pdf’
#
# en_fup_0000031697_2 100%[===================>]  55.26K   203KB/s    in 0.3s
#
# 2019-11-23 21:10:53 (203 KB/s) - ‘../../data/ASF_pdfs/en_fup_0000031697_20190912_111711.pdf’ saved [56587/56587]
#
# FINISHED --2019-11-23 21:10:53--
# Total wall clock time: 1.7s
# Downloaded: 1 files, 55K in 0.3s (203 KB/s)
# --2019-11-23 21:10:53--  https://www.oie.int/wahis_2/temp/reports/en_fup_0000032233_20191028_131553.pdf
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving www.oie.int (www.oie.int)... 51.254.148.117
# Connecting to www.oie.int (www.oie.int)|51.254.148.117|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 57776 (56K) [application/pdf]
# Saving to: ‘../../data/ASF_pdfs/en_fup_0000032233_20191028_131553.pdf’
#
# en_fup_0000032233_2 100%[===================>]  56.42K   207KB/s    in 0.3s
#
# 2019-11-23 21:10:55 (207 KB/s) - ‘../../data/ASF_pdfs/en_fup_0000032233_20191028_131553.pdf’ saved [57776/57776]
#
# FINISHED --2019-11-23 21:10:55--
# Total wall clock time: 1.8s
# Downloaded: 1 files, 56K in 0.3s (207 KB/s)
# --2019-11-23 21:10:55--  https://www.oie.int/wahis_2/temp/reports/en_fup_0000031750_20191024_173711.pdf
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving www.oie.int (www.oie.int)... 51.254.148.117
# Connecting to www.oie.int (www.oie.int)|51.254.148.117|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 55863 (55K) [application/pdf]
# Saving to: ‘../../data/ASF_pdfs/en_fup_0000031750_20191024_173711.pdf’
#
# en_fup_0000031750_2 100%[===================>]  54.55K   200KB/s    in 0.3s
#
# 2019-11-23 21:10:57 (200 KB/s) - ‘../../data/ASF_pdfs/en_fup_0000031750_20191024_173711.pdf’ saved [55863/55863]
#
# FINISHED --2019-11-23 21:10:57--
# Total wall clock time: 1.8s
# Downloaded: 1 files, 55K in 0.3s (200 KB/s)
# --2019-11-23 21:10:57--  https://www.oie.int/wahis_2/temp/reports/en_fup_0000031746_20191024_173421.pdf
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving www.oie.int (www.oie.int)... 51.254.148.117
# Connecting to www.oie.int (www.oie.int)|51.254.148.117|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54523 (53K) [application/pdf]
# Saving to: ‘../../data/ASF_pdfs/en_fup_0000031746_20191024_173421.pdf’
#
# en_fup_0000031746_2 100%[===================>]  53.25K   193KB/s    in 0.3s
#
# 2019-11-23 21:10:59 (193 KB/s) - ‘../../data/ASF_pdfs/en_fup_0000031746_20191024_173421.pdf’ saved [54523/54523]
#
# FINISHED --2019-11-23 21:10:59--
# Total wall clock time: 1.8s
# Downloaded: 1 files, 53K in 0.3s (193 KB/s)
# --2019-11-23 21:10:59--  https://www.oie.int/wahis_2/temp/reports/en_fup_0000031747_20191024_173539.pdf
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving www.oie.int (www.oie.int)... 51.254.148.117
# Connecting to www.oie.int (www.oie.int)|51.254.148.117|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54462 (53K) [application/pdf]
# Saving to: ‘../../data/ASF_pdfs/en_fup_0000031747_20191024_173539.pdf’
#
# en_fup_0000031747_2 100%[===================>]  53.19K   193KB/s    in 0.3s
#
# 2019-11-23 21:11:01 (193 KB/s) - ‘../../data/ASF_pdfs/en_fup_0000031747_20191024_173539.pdf’ saved [54462/54462]
#
# FINISHED --2019-11-23 21:11:01--
# Total wall clock time: 1.8s
# Downloaded: 1 files, 53K in 0.3s (193 KB/s)
# --2019-11-23 21:11:01--  https://www.oie.int/wahis_2/temp/reports/en_fup_0000031748_20191024_173629.pdf
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving www.oie.int (www.oie.int)... 51.254.148.117
# Connecting to www.oie.int (www.oie.int)|51.254.148.117|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54004 (53K) [application/pdf]
# Saving to: ‘../../data/ASF_pdfs/en_fup_0000031748_20191024_173629.pdf’
#
# en_fup_0000031748_2 100%[===================>]  52.74K   190KB/s    in 0.3s
#
# 2019-11-23 21:11:03 (190 KB/s) - ‘../../data/ASF_pdfs/en_fup_0000031748_20191024_173629.pdf’ saved [54004/54004]
#
# FINISHED --2019-11-23 21:11:03--
# Total wall clock time: 1.8s
# Downloaded: 1 files, 53K in 0.3s (190 KB/s)
# --2019-11-23 21:11:03--  https://www.oie.int/wahis_2/temp/reports/en_fup_0000031749_20191024_172832.pdf
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving www.oie.int (www.oie.int)... 51.254.148.117
# Connecting to www.oie.int (www.oie.int)|51.254.148.117|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54006 (53K) [application/pdf]
# Saving to: ‘../../data/ASF_pdfs/en_fup_0000031749_20191024_172832.pdf’
#
# en_fup_0000031749_2 100%[===================>]  52.74K   198KB/s    in 0.3s
#
# 2019-11-23 21:11:05 (198 KB/s) - ‘../../data/ASF_pdfs/en_fup_0000031749_20191024_172832.pdf’ saved [54006/54006]
#
# FINISHED --2019-11-23 21:11:05--
# Total wall clock time: 1.8s
# Downloaded: 1 files, 53K in 0.3s (198 KB/s)
# --2019-11-23 21:11:05--  https://www.oie.int/wahis_2/temp/reports/en_fup_0000032148_20191021_155119.pdf
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving www.oie.int (www.oie.int)... 51.254.148.117
# Connecting to www.oie.int (www.oie.int)|51.254.148.117|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 59409 (58K) [application/pdf]
# Saving to: ‘../../data/ASF_pdfs/en_fup_0000032148_20191021_155119.pdf’
#
# en_fup_0000032148_2 100%[===================>]  58.02K   207KB/s    in 0.3s
#
# 2019-11-23 21:11:07 (207 KB/s) - ‘../../data/ASF_pdfs/en_fup_0000032148_20191021_155119.pdf’ saved [59409/59409]
#
# FINISHED --2019-11-23 21:11:07--
# Total wall clock time: 1.8s
# Downloaded: 1 files, 58K in 0.3s (207 KB/s)
# --2019-11-23 21:11:07--  https://www.oie.int/wahis_2/temp/reports/en_fup_0000032362_20191115_115516.pdf
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving www.oie.int (www.oie.int)... 51.254.148.117
# Connecting to www.oie.int (www.oie.int)|51.254.148.117|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58329 (57K) [application/pdf]
# Saving to: ‘../../data/ASF_pdfs/en_fup_0000032362_20191115_115516.pdf’
#
# en_fup_0000032362_2 100%[===================>]  56.96K   211KB/s    in 0.3s
#
# 2019-11-23 21:11:09 (211 KB/s) - ‘../../data/ASF_pdfs/en_fup_0000032362_20191115_115516.pdf’ saved [58329/58329]
#
# FINISHED --2019-11-23 21:11:09--
# Total wall clock time: 1.7s
# Downloaded: 1 files, 57K in 0.3s (211 KB/s)
# --2019-11-23 21:11:09--  https://www.oie.int/wahis_2/temp/reports/en_fup_0000030205_20191115_123657.pdf
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving www.oie.int (www.oie.int)... 51.254.148.117
# Connecting to www.oie.int (www.oie.int)|51.254.148.117|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 56766 (55K) [application/pdf]
# Saving to: ‘../../data/ASF_pdfs/en_fup_0000030205_20191115_123657.pdf’
#
# en_fup_0000030205_2 100%[===================>]  55.44K   207KB/s    in 0.3s
#
# 2019-11-23 21:11:10 (207 KB/s) - ‘../../data/ASF_pdfs/en_fup_0000030205_20191115_123657.pdf’ saved [56766/56766]
#
# FINISHED --2019-11-23 21:11:10--
# Total wall clock time: 1.7s
# Downloaded: 1 files, 55K in 0.3s (207 KB/s)
# --2019-11-23 21:11:11--  https://www.oie.int/wahis_2/temp/reports/en_fup_0000032332_20191115_122844.pdf
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving www.oie.int (www.oie.int)... 51.254.148.117
# Connecting to www.oie.int (www.oie.int)|51.254.148.117|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 56010 (55K) [application/pdf]
# Saving to: ‘../../data/ASF_pdfs/en_fup_0000032332_20191115_122844.pdf’
#
# en_fup_0000032332_2 100%[===================>]  54.70K   188KB/s    in 0.3s
#
# 2019-11-23 21:11:12 (188 KB/s) - ‘../../data/ASF_pdfs/en_fup_0000032332_20191115_122844.pdf’ saved [56010/56010]
#
# FINISHED --2019-11-23 21:11:12--
# Total wall clock time: 1.9s
# Downloaded: 1 files, 55K in 0.3s (188 KB/s)
# --2019-11-23 21:11:13--  https://www.oie.int/wahis_2/temp/reports/en_fup_0000030215_20191107_173737.pdf
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving www.oie.int (www.oie.int)... 51.254.148.117
# Connecting to www.oie.int (www.oie.int)|51.254.148.117|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 57455 (56K) [application/pdf]
# Saving to: ‘../../data/ASF_pdfs/en_fup_0000030215_20191107_173737.pdf’
#
# en_fup_0000030215_2 100%[===================>]  56.11K   200KB/s    in 0.3s
#
# 2019-11-23 21:11:14 (200 KB/s) - ‘../../data/ASF_pdfs/en_fup_0000030215_20191107_173737.pdf’ saved [57455/57455]
#
# FINISHED --2019-11-23 21:11:14--
# Total wall clock time: 1.8s
# Downloaded: 1 files, 56K in 0.3s (200 KB/s)
# --2019-11-23 21:11:14--  https://www.oie.int/wahis_2/temp/reports/en_fup_0000031745_20191107_175059.pdf
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving www.oie.int (www.oie.int)... 51.254.148.117
# Connecting to www.oie.int (www.oie.int)|51.254.148.117|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58791 (57K) [application/pdf]
# Saving to: ‘../../data/ASF_pdfs/en_fup_0000031745_20191107_175059.pdf’
#
# en_fup_0000031745_2 100%[===================>]  57.41K   208KB/s    in 0.3s
#
# 2019-11-23 21:11:16 (208 KB/s) - ‘../../data/ASF_pdfs/en_fup_0000031745_20191107_175059.pdf’ saved [58791/58791]
#
# FINISHED --2019-11-23 21:11:16--
# Total wall clock time: 1.8s
# Downloaded: 1 files, 57K in 0.3s (208 KB/s)
# --2019-11-23 21:11:16--  https://www.oie.int/wahis_2/temp/reports/en_fup_0000031751_20191107_172324.pdf
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving www.oie.int (www.oie.int)... 51.254.148.117
# Connecting to www.oie.int (www.oie.int)|51.254.148.117|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 55800 (54K) [application/pdf]
# Saving to: ‘../../data/ASF_pdfs/en_fup_0000031751_20191107_172324.pdf’
#
# en_fup_0000031751_2 100%[===================>]  54.49K   197KB/s    in 0.3s
#
# 2019-11-23 21:11:18 (197 KB/s) - ‘../../data/ASF_pdfs/en_fup_0000031751_20191107_172324.pdf’ saved [55800/55800]
#
# FINISHED --2019-11-23 21:11:18--
# Total wall clock time: 1.8s
# Downloaded: 1 files, 54K in 0.3s (197 KB/s)
# --2019-11-23 21:11:18--  https://www.oie.int/wahis_2/temp/reports/en_fup_0000031752_20191107_170414.pdf
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving www.oie.int (www.oie.int)... 51.254.148.117
# Connecting to www.oie.int (www.oie.int)|51.254.148.117|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54024 (53K) [application/pdf]
# Saving to: ‘../../data/ASF_pdfs/en_fup_0000031752_20191107_170414.pdf’
#
# en_fup_0000031752_2 100%[===================>]  52.76K   192KB/s    in 0.3s
#
# 2019-11-23 21:11:20 (192 KB/s) - ‘../../data/ASF_pdfs/en_fup_0000031752_20191107_170414.pdf’ saved [54024/54024]
#
# FINISHED --2019-11-23 21:11:20--
# Total wall clock time: 1.8s
# Downloaded: 1 files, 53K in 0.3s (192 KB/s)
# --2019-11-23 21:11:20--  https://www.oie.int/wahis_2/temp/reports/en_fup_0000030204_20191107_171529.pdf
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving www.oie.int (www.oie.int)... 51.254.148.117
# Connecting to www.oie.int (www.oie.int)|51.254.148.117|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54121 (53K) [application/pdf]
# Saving to: ‘../../data/ASF_pdfs/en_fup_0000030204_20191107_171529.pdf’
#
# en_fup_0000030204_2 100%[===================>]  52.85K   184KB/s    in 0.3s
#
# 2019-11-23 21:11:22 (184 KB/s) - ‘../../data/ASF_pdfs/en_fup_0000030204_20191107_171529.pdf’ saved [54121/54121]
#
# FINISHED --2019-11-23 21:11:22--
# Total wall clock time: 1.8s
# Downloaded: 1 files, 53K in 0.3s (184 KB/s)

# %%
# !rm {pdfsDir}/*.pdf.* 2> /dev/null
pdfReports = !ls {pdfsDir}/*.pdf
pdfReports[1:10]
# Out:
# ['../../data/ASF_pdfs/en_fup_0000027533_20180813_175309.pdf',
#  '../../data/ASF_pdfs/en_fup_0000027570_20180816_175933.pdf',
#  '../../data/ASF_pdfs/en_fup_0000027688_20180907_184405.pdf',
#  '../../data/ASF_pdfs/en_fup_0000027689_20180907_184909.pdf',
#  '../../data/ASF_pdfs/en_fup_0000027690_20180907_184548.pdf',
#  '../../data/ASF_pdfs/en_fup_0000027691_20180907_184715.pdf',
#  '../../data/ASF_pdfs/en_fup_0000027809_20180904_134034.pdf',
#  '../../data/ASF_pdfs/en_fup_0000027839_20180906_133151.pdf',
#  '../../data/ASF_pdfs/en_fup_0000027845_20180907_105504.pdf']

# %% [markdown]
# # Translating pdf-files to xml-format

# %%
xmlsDir = "../../data/ASF_xmls"
# !rm -rf {xmlsDir}
# !mkdir -p {xmlsDir}

# %%
# will take some time because there are many reports from other countries about African swine fever
# that are needed to process but thrown away later
for report in pdfReports:
    if not os.path.exists(xmlsDir+"/"+report.split("/")[-1]+".xml"):
        # !pdftohtml -i -xml -q {report} {report}.xml 
        # !echo {report}
        # !sed -i '/Printed/d; /OIE Ref:/d; /Page [0-9].*\/[0-9]/d' {report}.xml
        # !mv {report}.xml {xmlsDir}
# Out:
# ../../data/ASF_pdfs/en_fup_0000030204_20191107_171529.pdf
# ../../data/ASF_pdfs/en_fup_0000030205_20191115_123657.pdf
# ../../data/ASF_pdfs/en_fup_0000030215_20191107_173737.pdf
# ../../data/ASF_pdfs/en_fup_0000031697_20190912_111711.pdf
# ../../data/ASF_pdfs/en_fup_0000031745_20191107_175059.pdf
# ../../data/ASF_pdfs/en_fup_0000031746_20191024_173421.pdf
# ../../data/ASF_pdfs/en_fup_0000031747_20191024_173539.pdf
# ../../data/ASF_pdfs/en_fup_0000031748_20191024_173629.pdf
# ../../data/ASF_pdfs/en_fup_0000031749_20191024_172832.pdf
# ../../data/ASF_pdfs/en_fup_0000031750_20191024_173711.pdf
# ../../data/ASF_pdfs/en_fup_0000031751_20191107_172324.pdf
# ../../data/ASF_pdfs/en_fup_0000031752_20191107_170414.pdf
# ../../data/ASF_pdfs/en_fup_0000031892_20190924_175316.pdf
# ../../data/ASF_pdfs/en_fup_0000032148_20191021_155119.pdf
# ../../data/ASF_pdfs/en_fup_0000032233_20191028_131553.pdf
# ../../data/ASF_pdfs/en_fup_0000032332_20191115_122844.pdf
# ../../data/ASF_pdfs/en_fup_0000032362_20191115_115516.pdf

# %%
xmlReports = !ls {xmlsDir}/*xml
print("Number of reports: %d"%len(xmlReports))
xmlReports[0:10]
# Out:
# Number of reports: 168
# ['../../data/ASF_xmls/en_fup_0000027458_20180806_155743.pdf.xml',
#  '../../data/ASF_xmls/en_fup_0000027533_20180813_175309.pdf.xml',
#  '../../data/ASF_xmls/en_fup_0000027570_20180816_175933.pdf.xml',
#  '../../data/ASF_xmls/en_fup_0000027688_20180907_184405.pdf.xml',
#  '../../data/ASF_xmls/en_fup_0000027689_20180907_184909.pdf.xml',
#  '../../data/ASF_xmls/en_fup_0000027690_20180907_184548.pdf.xml',
#  '../../data/ASF_xmls/en_fup_0000027691_20180907_184715.pdf.xml',
#  '../../data/ASF_xmls/en_fup_0000027809_20180904_134034.pdf.xml',
#  '../../data/ASF_xmls/en_fup_0000027839_20180906_133151.pdf.xml',
#  '../../data/ASF_xmls/en_fup_0000027845_20180907_105504.pdf.xml']

# %% [markdown]
# # One example of making a *soup* for a particular xml-file

# %%
indexReport = 6
xmlReport = xmlReports[indexReport]
infile = open(xmlReport,"r")
print(xmlReport)
contents = infile.read()
soup = BeautifulSoup(contents)
cells = soup.find_all('text')
cells = [cell.get_text() for cell in cells]
cells[0:80]
# Out:
# ../../data/ASF_xmls/en_fup_0000027691_20180907_184715.pdf.xml
# ['Follow-up report No.1',
#  "Report reference:  , Reference OIE : 27691, Report Date : 07/09/2018, Country : China (People's Rep. of)",
#  'Report Summary',
#  'Name of sender of the report',
#  'Dr Zhang Zhongqui',
#  'Telephone',
#  '(86-10) 591 928 28',
#  'Position',
#  'Director General',
#  'Fax',
#  '(86-10) 591 928 45',
#  'Address',
#  'No.11, Nongzhanguan Nanli ',
#  'Chaoyang District ',
#  'Beijing, 100125 ',
#  ' Beijing',
#  'Email',
#  'chinadelegate@agri.gov.cn',
#  'Date submitted to OIE',
#  '07/09/2018',
#  ' ',
#  'Animal type',
#  'Terrestrial',
#  'Date of report',
#  '07/09/2018',
#  'Disease',
#  'African swine fever',
#  'Date of start of the event',
#  '17/08/2018',
#  'Causal Agent',
#  'African swine fever virus',
#  'Date of confirmation of the event',
#  '22/08/2018',
#  'Reason',
#  'First occurrence of a listed disease',
#  'Diagnosis',
#  'Clinical, Laboratory (advanced)',
#  'Country or zone',
#  'a zone or compartment',
#  'Clinical signs',
#  'Yes',
#  'Number of reported outbreaks',
#  'submitted= 1, Draft= 0',
#  'Outbreak details',
#  'Province',
#  'Number of outbreaks',
#  'City',
#  'County',
#  'Unit Type',
#  'Location',
#  'Latitude',
#  'Longitude',
#  'Start Date',
#  'End Date:',
#  'Zhejiang-other report -',
#  'submitted',
#  '-',
#  'Wenzhou',
#  'Yueqing',
#  'Farm',
#  'Zhang ao Village',
#  '28.2',
#  '120.94',
#  '17/08/2018',
#  'Species',
#  'Measuring units',
#  'Susceptible',
#  'Cases',
#  'Deaths',
#  'Killed and disposed of',
#  'Slaughtered',
#  'Swine',
#  'Animals',
#  '1864',
#  '430',
#  '340',
#  '1524',
#  '0',
#  'Affected Population',
#  ' ']

# %%
# machinery
a = ['Province', 'Number of outbreaks', 'City', 'County', 'Unit Type', 'Location', 'Latitude', 
     'Longitude', 'Start Date', 'End Date:', 'Species', 'Measuring units', 'Susceptible', 'Cases', 'Deaths', 
     'Killed and disposed of', 'Slaughtered']
cells = np.delete(cells, [range(i,(i+len(a))) for i in range(len(cells)) if (cells[i:(i+len(a))]==a)], axis=0)
cells[:10]
# Out:
# array(['Follow-up report No.1',
#        "Report reference:  , Reference OIE : 27691, Report Date : 07/09/2018, Country : China (People's Rep. of)",
#        'Report Summary', 'Name of sender of the report',
#        'Dr Zhang Zhongqui', 'Telephone', '(86-10) 591 928 28', 'Position',
#        'Director General', 'Fax'], dtype='<U280')

# %%
outbreak_indexes = [[i for i,s in enumerate(cells) if s=='Latitude'][0]-2]
outbreak_indexes = outbreak_indexes + [i for i,s in enumerate(cells) if (i>=outbreak_indexes[0] and "Affected Population" in s)]
str(outbreak_indexes)
# Out:
# '[48, 78]'

# %%
df = pd.DataFrame()
entity = []
zz1 = [i for i,cell in enumerate(cells) if cell=='Date submitted to OIE'][0] # for Date submitted to OIE
zz2 = [i for i,cell in enumerate(cells) if cell=='Date of report'][0] # Date of report
zz3 = [i for i,cell in enumerate(cells) if cell=='Date of confirmation of the event'][0] #Date of confirmation of the event
for idx0,idx1 in zip(outbreak_indexes,shift(outbreak_indexes,1)):
    if idx0<idx1 and (idx1-idx0)>10:
        cls = cells[idx0:idx1]
        # some machinery
        xx = [i for i,cell in enumerate(cls) if cell=='Latitude'][0]
        xx = [i for i,cell in enumerate(cls) 
              if i>xx+7 and #+7 here is a small technical adjustment
                  (cell.isdigit() or 
                   (("." in cell or "," in cell) and cell.replace(",",".").split(".")[1].isdigit()))][0]
        yy = [i for i,cell in enumerate(cls) if cell=='Species'][-1]
        try:
            yy = [i for i,cell in enumerate(cls) if cell=='Species'][-1]
            delta = (1 if "/" in cls[yy-2] else 0)
        except:
            delta = 0
        zz = [i for i,cell in enumerate(cls) if cell=='End Date:'][0]
        delta_z = 1
        while ((cls[zz+delta_z]!='-')&(zz+delta_z<xx)):
            delta_z = delta_z+1
        entity.append({
            'No': indexReport, # for reference
            'date_report': cells[zz2+1],
            'date_submission': cells[zz1+1],
            'date_confirmation': cells[zz3+1],
            'province': cls[zz+1].split("-")[0],
            'location': "_".join(cls[(zz+delta_z+1):xx]).replace(","," "),
            'lat': cls[xx].replace(",",".").split()[-1], #latitude (use of split(" ") b/c there are some inconsistency in few xmls)
            'long': cls[xx+1].replace(",","."), #Longitude
            'start': cls[xx+2], #Start date
            'end': (cls[xx+3] if delta else np.nan), #End date
            'species': (cls[-8].split("(")[0] if cls[-7][-1]==')' else cls[-7]), #Species
            'susceptible': (int(cls[-5]) if cls[-5].isdigit() else np.nan), #Susceptibles
            'cases': (int(cls[-4]) if cls[-4].isdigit() else np.nan), #Cases
            'deaths': (int(cls[-3]) if cls[-3].isdigit() else np.nan), #Deaths
            'destroyed': (int(cls[-2]) if cls[-2].isdigit() else np.nan), #Destroyed
            'slaughtered': (int(cls[-1]) if cls[-1].isdigit() else np.nan), #Slaughtered
            'report_name': xmlReport.split("/")[-1].split(".")[0]
        })
        
(pd.DataFrame.from_dict(entity)[list(entity[0].keys())])
# Out:
#    No date_report date_submission date_confirmation  province  \
# 0   6  07/09/2018      07/09/2018        22/08/2018  Zhejiang
#
#                                 location   lat    long       start  end  \
# 0  Wenzhou_Yueqing_Farm_Zhang ao Village  28.2  120.94  17/08/2018  NaN
#
#   species  susceptible  cases  deaths  destroyed  slaughtered  \
# 0   Swine         1864    430     340       1524            0
#
#                          report_name
# 0  en_fup_0000027691_20180907_184715

# %% [markdown]
# # Accumulating the final dataset from all retrieved reports

# %%
entity = []
for indexReport, xmlReport in enumerate(xmlReports):
    entity.append({'No': indexReport, 'report': (xmlReport.split("/")[-1])[:-8]})
pd.DataFrame.from_dict(entity)[list(entity[0].keys())].to_csv("../../data/ASF_reports_indexing.csv",index=False,sep=",")

# %%
entity = []
for indexReport, xmlReport in enumerate(xmlReports):
    print ([indexReport,xmlReport])
    infile = open(xmlReport,"r")
    contents = infile.read()
    soup = BeautifulSoup(contents)
    cells = soup.find_all('text')
    cells = [cell.get_text() for cell in cells]
    
    a = ['Province', 'Number of outbreaks', 'City', 'County', 'Unit Type', 'Location', 'Latitude', 
     'Longitude', 'Start Date', 'End Date:', 'Species', 'Measuring units', 'Susceptible', 'Cases', 'Deaths', 
     'Killed and disposed of', 'Slaughtered']
    cells = np.delete(cells, [range(i,(i+len(a))) for i in range(len(cells)) if (cells[i:(i+len(a))]==a)], axis=0)
    
    outbreak_indexes = [[i for i,s in enumerate(cells) if s=='Latitude'][0]]
    outbreak_indexes = outbreak_indexes + [i for i,s in enumerate(cells) if (i>=outbreak_indexes[0] and "Affected Population" in s)]

    zz1 = [i for i,cell in enumerate(cells) if cell=='Date submitted to OIE'][0] # for Date submitted to OIE
    zz2 = [i for i,cell in enumerate(cells) if cell=='Date of report'][0] # Date of report
    zz3 = [i for i,cell in enumerate(cells) if cell=='Date of confirmation of the event'][0] #Date of confirmation of the event

    order = 1
    for idx0,idx1 in zip(outbreak_indexes,shift(outbreak_indexes,1)):
        if idx0<idx1 and (idx1-idx0)>10:
            cls = cells[idx0:idx1]
            # some machinery
            xx = [i for i,cell in enumerate(cls) if cell=='Latitude'][0]
            xx = [i for i,cell in enumerate(cls) 
                  if i>xx and #+7 here is a small technical adjustment
                      (cell.isdigit() or 
                       (("." in cell or "," in cell) and cell.replace(",",".").split(".")[1].isdigit()))][0]
            try:
                yy = [i for i,cell in enumerate(cls) if cell=='Species'][-1]
                delta = (1 if "/" in cls[yy-2] else 0)
            except:
                delta = 0
            zz = [i for i,cell in enumerate(cls) if cell=='End Date:'][0]
            delta_z = 1
            while ((cls[zz+delta_z]!='-')&(zz+delta_z<xx)):
                delta_z = delta_z+1
            entity.append({
                'No': indexReport, # for reference
                'report': xmlReport.split("/")[-1].split(".")[0],
                'report_info': cls[zz+1].split("-")[1],
                'order': order,
                'date_report': cells[zz2+1],
                'date_submission': cells[zz1+1],
                'date_confirmation': cells[zz3+1],
                'province': cls[zz+1].split("-")[0],
                'location': "_".join(cls[(zz+delta_z+1):xx]).replace(","," "),
                'lat': cls[xx].replace(",",".").split()[-1], #latitude (use of split(" ") b/c there are some inconsistency in few xmls)
                'long': cls[xx+1].replace(",","."), #Longitude
                'start': cls[xx+2], #Start date
                'end': (cls[xx+3] if delta else np.nan), #End date
                'species': (cls[-8].split("(")[0] if cls[-7][-1]==')' else cls[-7]), #Species
                'susceptible': (int(cls[-5]) if cls[-5].isdigit() else np.nan), #Susceptibles
                'cases': (int(cls[-4]) if cls[-4].isdigit() else np.nan), #Cases
                'deaths': (int(cls[-3]) if cls[-3].isdigit() else np.nan), #Deaths
                'destroyed': (int(cls[-2]) if cls[-2].isdigit() else np.nan), #Destroyed
                'slaughtered': (int(cls[-1]) if cls[-1].isdigit() else np.nan) #Slaughtered
            })
            order = order + 1
            
pd.DataFrame.from_dict(entity)[list(entity[0].keys())].to_csv("../../data/ASF_data.csv",
                                                              na_rep = 'NA',
                                                              index=False,
                                                              sep=",")
# Out:
# [0, '../../data/ASF_xmls/en_fup_0000027458_20180806_155743.pdf.xml']
# [1, '../../data/ASF_xmls/en_fup_0000027533_20180813_175309.pdf.xml']
# [2, '../../data/ASF_xmls/en_fup_0000027570_20180816_175933.pdf.xml']
# [3, '../../data/ASF_xmls/en_fup_0000027688_20180907_184405.pdf.xml']
# [4, '../../data/ASF_xmls/en_fup_0000027689_20180907_184909.pdf.xml']
# [5, '../../data/ASF_xmls/en_fup_0000027690_20180907_184548.pdf.xml']
# [6, '../../data/ASF_xmls/en_fup_0000027691_20180907_184715.pdf.xml']
# [7, '../../data/ASF_xmls/en_fup_0000027809_20180904_134034.pdf.xml']
# [8, '../../data/ASF_xmls/en_fup_0000027839_20180906_133151.pdf.xml']
# [9, '../../data/ASF_xmls/en_fup_0000027845_20180907_105504.pdf.xml']
# [10, '../../data/ASF_xmls/en_fup_0000027846_20180907_110550.pdf.xml']
# [11, '../../data/ASF_xmls/en_fup_0000027856_20180910_192244.pdf.xml']
# [12, '../../data/ASF_xmls/en_fup_0000027857_20180910_190506.pdf.xml']
# [13, '../../data/ASF_xmls/en_fup_0000027897_20180911_160445.pdf.xml']
# [14, '../../data/ASF_xmls/en_fup_0000027932_20180914_185340.pdf.xml']
# [15, '../../data/ASF_xmls/en_fup_0000027933_20180914_175722.pdf.xml']
# [16, '../../data/ASF_xmls/en_fup_0000027934_20180914_180827.pdf.xml']
# [17, '../../data/ASF_xmls/en_fup_0000027957_20180917_170311.pdf.xml']
# [18, '../../data/ASF_xmls/en_fup_0000027986_20180917_184003.pdf.xml']
# [19, '../../data/ASF_xmls/en_fup_0000028035_20181001_180714.pdf.xml']
# [20, '../../data/ASF_xmls/en_fup_0000028056_20180925_125341.pdf.xml']
# [21, '../../data/ASF_xmls/en_fup_0000028097_20180928_170447.pdf.xml']
# [22, '../../data/ASF_xmls/en_fup_0000028098_20180928_170201.pdf.xml']
# [23, '../../data/ASF_xmls/en_fup_0000028099_20180928_170343.pdf.xml']
# [24, '../../data/ASF_xmls/en_fup_0000028122_20181004_131708.pdf.xml']
# [25, '../../data/ASF_xmls/en_fup_0000028200_20181011_135939.pdf.xml']
# [26, '../../data/ASF_xmls/en_fup_0000028229_20181012_132619.pdf.xml']
# [27, '../../data/ASF_xmls/en_fup_0000028242_20181015_125935.pdf.xml']
# [28, '../../data/ASF_xmls/en_fup_0000028275_20181017_122710.pdf.xml']
# [29, '../../data/ASF_xmls/en_fup_0000028291_20181018_194247.pdf.xml']
# [30, '../../data/ASF_xmls/en_fup_0000028348_20181024_113452.pdf.xml']
# [31, '../../data/ASF_xmls/en_fup_0000028424_20181029_141502.pdf.xml']
# [32, '../../data/ASF_xmls/en_fup_0000028449_20181102_144117.pdf.xml']
# [33, '../../data/ASF_xmls/en_fup_0000028466_20181102_143759.pdf.xml']
# [34, '../../data/ASF_xmls/en_fup_0000028467_20181102_144252.pdf.xml']
# [35, '../../data/ASF_xmls/en_fup_0000028476_20181102_143609.pdf.xml']
# [36, '../../data/ASF_xmls/en_fup_0000028516_20181105_173837.pdf.xml']
# [37, '../../data/ASF_xmls/en_fup_0000028540_20181106_175332.pdf.xml']
# [38, '../../data/ASF_xmls/en_fup_0000028575_20181109_173542.pdf.xml']
# [39, '../../data/ASF_xmls/en_fup_0000028576_20181109_170053.pdf.xml']
# [40, '../../data/ASF_xmls/en_fup_0000028599_20181112_124801.pdf.xml']
# [41, '../../data/ASF_xmls/en_fup_0000028626_20181115_120136.pdf.xml']
# [42, '../../data/ASF_xmls/en_fup_0000028644_20181119_183432.pdf.xml']
# [43, '../../data/ASF_xmls/en_fup_0000028665_20181122_134358.pdf.xml']
# [44, '../../data/ASF_xmls/en_fup_0000028666_20181122_135736.pdf.xml']
# [45, '../../data/ASF_xmls/en_fup_0000028668_20181119_183745.pdf.xml']
# [46, '../../data/ASF_xmls/en_fup_0000028683_20181121_131005.pdf.xml']
# [47, '../../data/ASF_xmls/en_fup_0000028702_20181122_161808.pdf.xml']
# [48, '../../data/ASF_xmls/en_fup_0000028734_20181126_125430.pdf.xml']
# [49, '../../data/ASF_xmls/en_fup_0000028756_20181127_163327.pdf.xml']
# [50, '../../data/ASF_xmls/en_fup_0000028756_20181218_141712.pdf.xml']
# [51, '../../data/ASF_xmls/en_fup_0000028798_20181203_164700.pdf.xml']
# [52, '../../data/ASF_xmls/en_fup_0000028839_20181207_144231.pdf.xml']
# [53, '../../data/ASF_xmls/en_fup_0000028842_20181207_144009.pdf.xml']
# [54, '../../data/ASF_xmls/en_fup_0000028844_20181207_174956.pdf.xml']
# [55, '../../data/ASF_xmls/en_fup_0000028859_20181207_144646.pdf.xml']
# [56, '../../data/ASF_xmls/en_fup_0000028860_20181207_183339.pdf.xml']
# [57, '../../data/ASF_xmls/en_fup_0000028891_20181211_130042.pdf.xml']
# [58, '../../data/ASF_xmls/en_fup_0000028892_20181211_130208.pdf.xml']
# [59, '../../data/ASF_xmls/en_fup_0000028923_20181214_132032.pdf.xml']
# [60, '../../data/ASF_xmls/en_fup_0000028981_20181218_194444.pdf.xml']
# [61, '../../data/ASF_xmls/en_fup_0000028982_20181218_194209.pdf.xml']
# [62, '../../data/ASF_xmls/en_fup_0000028993_20181220_201124.pdf.xml']
# [63, '../../data/ASF_xmls/en_fup_0000029012_20181226_144537.pdf.xml']
# [64, '../../data/ASF_xmls/en_fup_0000029025_20181226_202950.pdf.xml']
# [65, '../../data/ASF_xmls/en_fup_0000029047_20181226_202431.pdf.xml']
# [66, '../../data/ASF_xmls/en_fup_0000029049_20181226_203450.pdf.xml']
# [67, '../../data/ASF_xmls/en_fup_0000029084_20190110_125143.pdf.xml']
# [68, '../../data/ASF_xmls/en_fup_0000029085_20190102_163730.pdf.xml']
# [69, '../../data/ASF_xmls/en_fup_0000029090_20190109_192644.pdf.xml']
# [70, '../../data/ASF_xmls/en_fup_0000029091_20190109_191641.pdf.xml']
# [71, '../../data/ASF_xmls/en_fup_0000029092_20190109_195342.pdf.xml']
# [72, '../../data/ASF_xmls/en_fup_0000029094_20190109_203132.pdf.xml']
# [73, '../../data/ASF_xmls/en_fup_0000029095_20190109_185637.pdf.xml']
# [74, '../../data/ASF_xmls/en_fup_0000029096_20190109_201006.pdf.xml']
# [75, '../../data/ASF_xmls/en_fup_0000029097_20190103_140407.pdf.xml']
# [76, '../../data/ASF_xmls/en_fup_0000029218_20190118_140437.pdf.xml']
# [77, '../../data/ASF_xmls/en_fup_0000029221_20190118_173246.pdf.xml']
# [78, '../../data/ASF_xmls/en_fup_0000029222_20190118_142522.pdf.xml']
# [79, '../../data/ASF_xmls/en_fup_0000029223_20190118_141336.pdf.xml']
# [80, '../../data/ASF_xmls/en_fup_0000029224_20190118_143250.pdf.xml']
# [81, '../../data/ASF_xmls/en_fup_0000029262_20190121_182326.pdf.xml']
# [82, '../../data/ASF_xmls/en_fup_0000029568_20190225_190606.pdf.xml']
# [83, '../../data/ASF_xmls/en_fup_0000029569_20190225_175019.pdf.xml']
# [84, '../../data/ASF_xmls/en_fup_0000029570_20190225_201145.pdf.xml']
# [85, '../../data/ASF_xmls/en_fup_0000029571_20190225_173609.pdf.xml']
# [86, '../../data/ASF_xmls/en_fup_0000029572_20190225_192126.pdf.xml']
# [87, '../../data/ASF_xmls/en_fup_0000029573_20190225_184210.pdf.xml']
# [88, '../../data/ASF_xmls/en_fup_0000029574_20190225_175755.pdf.xml']
# [89, '../../data/ASF_xmls/en_fup_0000029694_20190226_144250.pdf.xml']
# [90, '../../data/ASF_xmls/en_fup_0000029774_20190311_140102.pdf.xml']
# [91, '../../data/ASF_xmls/en_fup_0000029831_20190314_125755.pdf.xml']
# [92, '../../data/ASF_xmls/en_fup_0000030052_20190408_125316.pdf.xml']
# [93, '../../data/ASF_xmls/en_fup_0000030088_20190408_192150.pdf.xml']
# [94, '../../data/ASF_xmls/en_fup_0000030139_20190415_152558.pdf.xml']
# [95, '../../data/ASF_xmls/en_fup_0000030204_20191107_171529.pdf.xml']
# [96, '../../data/ASF_xmls/en_fup_0000030205_20191115_123657.pdf.xml']
# [97, '../../data/ASF_xmls/en_fup_0000030208_20190524_142833.pdf.xml']
# [98, '../../data/ASF_xmls/en_fup_0000030215_20191107_173737.pdf.xml']
# [99, '../../data/ASF_xmls/en_fup_0000030253_20190424_140026.pdf.xml']
# [100, '../../data/ASF_xmls/en_fup_0000030554_20190521_165815.pdf.xml']
# [101, '../../data/ASF_xmls/en_fup_0000030635_20190529_151837.pdf.xml']
# [102, '../../data/ASF_xmls/en_fup_0000030636_20190603_134334.pdf.xml']
# [103, '../../data/ASF_xmls/en_fup_0000030657_20190530_133450.pdf.xml']
# [104, '../../data/ASF_xmls/en_fup_0000030681_20190603_134021.pdf.xml']
# [105, '../../data/ASF_xmls/en_fup_0000030749_20190621_162253.pdf.xml']
# [106, '../../data/ASF_xmls/en_fup_0000030822_20190624_185302.pdf.xml']
# [107, '../../data/ASF_xmls/en_fup_0000030914_20190701_113712.pdf.xml']
# [108, '../../data/ASF_xmls/en_fup_0000031019_20190709_170615.pdf.xml']
# [109, '../../data/ASF_xmls/en_fup_0000031062_20190715_115910.pdf.xml']
# [110, '../../data/ASF_xmls/en_fup_0000031125_20190719_182543.pdf.xml']
# [111, '../../data/ASF_xmls/en_fup_0000031308_20190808_123558.pdf.xml']
# [112, '../../data/ASF_xmls/en_fup_0000031340_20190809_165150.pdf.xml']
# [113, '../../data/ASF_xmls/en_fup_0000031548_20190828_113047.pdf.xml']
# [114, '../../data/ASF_xmls/en_fup_0000031697_20190912_111711.pdf.xml']
# [115, '../../data/ASF_xmls/en_fup_0000031745_20191107_175059.pdf.xml']
# [116, '../../data/ASF_xmls/en_fup_0000031746_20191024_173421.pdf.xml']
# [117, '../../data/ASF_xmls/en_fup_0000031747_20191024_173539.pdf.xml']
# [118, '../../data/ASF_xmls/en_fup_0000031748_20191024_173629.pdf.xml']
# [119, '../../data/ASF_xmls/en_fup_0000031749_20191024_172832.pdf.xml']
# [120, '../../data/ASF_xmls/en_fup_0000031750_20191024_173711.pdf.xml']
# [121, '../../data/ASF_xmls/en_fup_0000031751_20191107_172324.pdf.xml']
# [122, '../../data/ASF_xmls/en_fup_0000031752_20191107_170414.pdf.xml']
# [123, '../../data/ASF_xmls/en_fup_0000031892_20190924_175316.pdf.xml']
# [124, '../../data/ASF_xmls/en_fup_0000032148_20191021_155119.pdf.xml']
# [125, '../../data/ASF_xmls/en_fup_0000032233_20191028_131553.pdf.xml']
# [126, '../../data/ASF_xmls/en_fup_0000032332_20191115_122844.pdf.xml']
# [127, '../../data/ASF_xmls/en_fup_0000032362_20191115_115516.pdf.xml']
# [128, '../../data/ASF_xmls/en_imm_0000027442_20180803_155752.pdf.xml']
# [129, '../../data/ASF_xmls/en_imm_0000027568_20180816_165812.pdf.xml']
# [130, '../../data/ASF_xmls/en_imm_0000027598_20180820_154827.pdf.xml']
# [131, '../../data/ASF_xmls/en_imm_0000027636_20180823_183422.pdf.xml']
# [132, '../../data/ASF_xmls/en_imm_0000027741_20180831_161124.pdf.xml']
# [133, '../../data/ASF_xmls/en_imm_0000027819_20180905_145015.pdf.xml']
# [134, '../../data/ASF_xmls/en_imm_0000027959_20180917_164758.pdf.xml']
# [135, '../../data/ASF_xmls/en_imm_0000028033_20180921_151108.pdf.xml']
# [136, '../../data/ASF_xmls/en_imm_0000028249_20181015_120016.pdf.xml']
# [137, '../../data/ASF_xmls/en_imm_0000028300_20181018_173444.pdf.xml']
# [138, '../../data/ASF_xmls/en_imm_0000028351_20181024_114554.pdf.xml']
# [139, '../../data/ASF_xmls/en_imm_0000028369_20181024_123506.pdf.xml']
# [140, '../../data/ASF_xmls/en_imm_0000028398_20181026_150638.pdf.xml']
# [141, '../../data/ASF_xmls/en_imm_0000028517_20181105_171340.pdf.xml']
# [142, '../../data/ASF_xmls/en_imm_0000028561_20181108_174459.pdf.xml']
# [143, '../../data/ASF_xmls/en_imm_0000028578_20181109_160525.pdf.xml']
# [144, '../../data/ASF_xmls/en_imm_0000028580_20181109_154413.pdf.xml']
# [145, '../../data/ASF_xmls/en_imm_0000028645_20181119_161110.pdf.xml']
# [146, '../../data/ASF_xmls/en_imm_0000028669_20181119_160039.pdf.xml']
# [147, '../../data/ASF_xmls/en_imm_0000028732_20181126_170427.pdf.xml']
# [148, '../../data/ASF_xmls/en_imm_0000028840_20181207_141323.pdf.xml']
# [149, '../../data/ASF_xmls/en_imm_0000028924_20181214_150507.pdf.xml']
# [150, '../../data/ASF_xmls/en_imm_0000029007_20181220_163016.pdf.xml']
# [151, '../../data/ASF_xmls/en_imm_0000029190_20190114_183016.pdf.xml']
# [152, '../../data/ASF_xmls/en_imm_0000029199_20190115_145429.pdf.xml']
# [153, '../../data/ASF_xmls/en_imm_0000029266_20190121_182029.pdf.xml']
# [154, '../../data/ASF_xmls/en_imm_0000029519_20190213_145251.pdf.xml']
# [155, '../../data/ASF_xmls/en_imm_0000029594_20190225_162359.pdf.xml']
# [156, '../../data/ASF_xmls/en_imm_0000029625_20190222_120944.pdf.xml']
# [157, '../../data/ASF_xmls/en_imm_0000029634_20190225_155911.pdf.xml']
# [158, '../../data/ASF_xmls/en_imm_0000029664_20190226_125143.pdf.xml']
# [159, '../../data/ASF_xmls/en_imm_0000029700_20190301_145149.pdf.xml']
# [160, '../../data/ASF_xmls/en_imm_0000029922_20190325_171519.pdf.xml']
# [161, '../../data/ASF_xmls/en_imm_0000030007_20190417_113154.pdf.xml']
# [162, '../../data/ASF_xmls/en_imm_0000030048_20190408_124806.pdf.xml']
# [163, '../../data/ASF_xmls/en_imm_0000030086_20190408_180808.pdf.xml']
# [164, '../../data/ASF_xmls/en_imm_0000030234_20190423_154642.pdf.xml']
# [165, '../../data/ASF_xmls/en_imm_0000030552_20190521_132453.pdf.xml']
# [166, '../../data/ASF_xmls/en_imm_0000030824_20190625_141729.pdf.xml']
# [167, '../../data/ASF_xmls/en_imm_0000031265_20190808_154111.pdf.xml']

# %%
print("Haha, finished!")
# Out:
# Haha, finished!
